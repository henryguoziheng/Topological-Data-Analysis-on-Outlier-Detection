# %%
# !pip install data-depth
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting data-depth
#   Downloading data_depth-1.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.6/356.6 KB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from data-depth) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from data-depth) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from data-depth) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->data-depth) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->data-depth) (3.1.0)
# Installing collected packages: data-depth
# Successfully installed data-depth-1.0.0

# %%
import numpy as np
from depth.multivariate import halfspace
mat1=[[1, 0, 0],[0, 2, 0],[0, 0, 1]]
mat2=[[1, 0, 0],[0, 1, 0],[0, 0, 1]]
x = np.random.multivariate_normal([1,1,1], mat2, 10)
data = np.random.multivariate_normal([0,0,0], mat1, 200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f707f08d729e> in <cell line: 2>()
#       1 import numpy as np
# ----> 2 from depth.multivariate import halfspace
#       3 mat1=[[1, 0, 0],[0, 2, 0],[0, 0, 1]]
#       4 mat2=[[1, 0, 0],[0, 1, 0],[0, 0, 1]]
#       5 x = np.random.multivariate_normal([1,1,1], mat2, 10)
#
# /usr/local/lib/python3.9/dist-packages/depth/multivariate/__init__.py in <module>
# ----> 1 from depth.multivariate.Depth_approximation import depth_approximation
#       2 from depth.multivariate.BetaSkeleton import betaSkeleton
#       3 from depth.multivariate.Halfspace import halfspace
#       4 from depth.multivariate.L2 import L2
#       5 from depth.multivariate.Mahalanobis import mahalanobis
#
# /usr/local/lib/python3.9/dist-packages/depth/multivariate/Depth_approximation.py in <module>
#      14
#      15
# ---> 16     libr=CDLL(ddalpha_exact[0])
#      17     libRom=CDLL(ddalpha_approx[0])
#      18
#
# NameError: name 'ddalpha_exact' is not defined
